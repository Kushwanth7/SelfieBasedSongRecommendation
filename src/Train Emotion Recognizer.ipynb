# %%
from trainEmotions import test_emotionTraining
test_emotionTraining()
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 68.970588 %
#      epoch 1, minibatch 143/143, test error of best model 69.617647 %
# training @ iter =  200
# epoch 2, minibatch 143/143, validation error 62.647059 %
#      epoch 2, minibatch 143/143, test error of best model 63.558824 %
# training @ iter =  300
# training @ iter =  400
# epoch 3, minibatch 143/143, validation error 60.352941 %
#      epoch 3, minibatch 143/143, test error of best model 60.264706 %
# training @ iter =  500
# epoch 4, minibatch 143/143, validation error 59.147059 %
#      epoch 4, minibatch 143/143, test error of best model 58.676471 %
# training @ iter =  600
# training @ iter =  700
# epoch 5, minibatch 143/143, validation error 58.411765 %
#      epoch 5, minibatch 143/143, test error of best model 56.882353 %
# training @ iter =  800
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining()
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 69.000000 %
#      epoch 1, minibatch 143/143, test error of best model 69.617647 %
# training @ iter =  200
# epoch 2, minibatch 143/143, validation error 62.676471 %
#      epoch 2, minibatch 143/143, test error of best model 63.529412 %
# training @ iter =  300
# training @ iter =  400
# epoch 3, minibatch 143/143, validation error 60.352941 %
#      epoch 3, minibatch 143/143, test error of best model 60.382353 %
# training @ iter =  500
# epoch 4, minibatch 143/143, validation error 59.058824 %
#      epoch 4, minibatch 143/143, test error of best model 58.676471 %
# training @ iter =  600
# training @ iter =  700
# epoch 5, minibatch 143/143, validation error 58.529412 %
#      epoch 5, minibatch 143/143, test error of best model 56.941176 %
# training @ iter =  800
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=100)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 69.000000 %
#      epoch 1, minibatch 143/143, test error of best model 69.647059 %
# training @ iter =  200
# epoch 2, minibatch 143/143, validation error 62.647059 %
#      epoch 2, minibatch 143/143, test error of best model 63.558824 %
# training @ iter =  300
# training @ iter =  400
# epoch 3, minibatch 143/143, validation error 60.382353 %
#      epoch 3, minibatch 143/143, test error of best model 60.323529 %
# training @ iter =  500
# epoch 4, minibatch 143/143, validation error 59.176471 %
#      epoch 4, minibatch 143/143, test error of best model 58.735294 %
# training @ iter =  600
# training @ iter =  700
# epoch 5, minibatch 143/143, validation error 58.500000 %
#      epoch 5, minibatch 143/143, test error of best model 57.058824 %
# training @ iter =  800
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=2)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 69.000000 %
#      epoch 1, minibatch 143/143, test error of best model 69.617647 %
# training @ iter =  200
# epoch 2, minibatch 143/143, validation error 62.676471 %
#      epoch 2, minibatch 143/143, test error of best model 63.529412 %
# Optimization complete.
# Using gpu device 0: GRID K520
# The training process for function test_emotionTraining ran for 0.75m
# Best validation score of 62.676471 % obtained at iteration 286, with test performance 63.529412 %
# Training the model complete
# Saving the model complete
# List of probabilities predicted = [[ 0.1806142   0.01872174  0.17765258 ...,  0.12724034  0.10487006
#    0.15973163]
#  [ 0.12942672  0.01146151  0.13374725 ...,  0.15963177  0.05644579
#    0.18062103]
#  [ 0.13904606  0.01611088  0.11340422 ...,  0.15228502  0.13777085
#    0.22168134]
#  ...,
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=1,batch_size=1)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 5000
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# training @ iter =  3300
# training @ iter =  3400
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=1,batch_size=1)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 5000
# training @ iter =  0
# training @ iter =  100
# training @ iter =  200
# training @ iter =  300
# training @ iter =  400
# training @ iter =  500
# training @ iter =  600
# training @ iter =  700
# training @ iter =  800
# training @ iter =  900
# training @ iter =  1000
# training @ iter =  1100
# training @ iter =  1200
# training @ iter =  1300
# training @ iter =  1400
# training @ iter =  1500
# training @ iter =  1600
# training @ iter =  1700
# training @ iter =  1800
# training @ iter =  1900
# training @ iter =  2000
# training @ iter =  2100
# training @ iter =  2200
# training @ iter =  2300
# training @ iter =  2400
# training @ iter =  2500
# training @ iter =  2600
# training @ iter =  2700
# training @ iter =  2800
# training @ iter =  2900
# training @ iter =  3000
# training @ iter =  3100
# training @ iter =  3200
# training @ iter =  3300
# training @ iter =  3400
# ...

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=1)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 69.000000 %
#      epoch 1, minibatch 143/143, test error of best model 69.617647 %
# Optimization complete.
# Using gpu device 0: GRID K520
# The training process for function test_emotionTraining ran for 0.37m
# Best validation score of 69.000000 % obtained at iteration 143, with test performance 69.617647 %
# Training the model complete
# Saving the model complete
# List of probabilities predicted = [[ 0.15994686  0.01388849  0.15749703 ...,  0.13873808  0.16524431
#    0.17441344]
#  [ 0.14563243  0.01273337  0.142334   ...,  0.137289    0.14379194
#    0.18081097]
#  [ 0.15045662  0.01651549  0.10790657 ...,  0.18141715  0.08348347
#    0.21727996]
#  ...,
#  [ 0.1473195   0.01335505  0.16083555 ...,  0.12253685  0.19748785
#    0.16836022]
#  [ 0.20394534  0.02057636  0.1328166  ...,  0.21387917  0.08364917
# ...

# %%
from loadModel import loadModel
loadModel()
# Out:
# 35887
# ... building the model
# List of probabilities predicted = [[ 0.15994686  0.01388849  0.15749703 ...,  0.13873808  0.16524431
#    0.17441344]
#  [ 0.14563243  0.01273337  0.142334   ...,  0.137289    0.14379194
#    0.18081097]
#  [ 0.15045662  0.01651549  0.10790657 ...,  0.18141715  0.08348347
#    0.21727996]
#  ...,
#  [ 0.1473195   0.01335505  0.16083555 ...,  0.12253685  0.19748785
#    0.16836022]
#  [ 0.20394534  0.02057636  0.1328166  ...,  0.21387917  0.08364917
#    0.17366979]
#  [ 0.16741168  0.01405426  0.153523   ...,  0.14500931  0.16366526
#    0.1763798 ]]

# %%
from trainEmotions import test_emotionTraining
test_emotionTraining(n_epochs=50)
# Out:
# 35887
# ... building the model
# ... training
# validation_frequency = 143
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 143/143, validation error 69.000000 %
#      epoch 1, minibatch 143/143, test error of best model 69.617647 %
# training @ iter =  200
# epoch 2, minibatch 143/143, validation error 62.617647 %
#      epoch 2, minibatch 143/143, test error of best model 63.558824 %
# training @ iter =  300
# training @ iter =  400
# epoch 3, minibatch 143/143, validation error 60.352941 %
#      epoch 3, minibatch 143/143, test error of best model 60.382353 %
# training @ iter =  500
# epoch 4, minibatch 143/143, validation error 59.176471 %
#      epoch 4, minibatch 143/143, test error of best model 58.617647 %
# training @ iter =  600
# training @ iter =  700
# epoch 5, minibatch 143/143, validation error 58.500000 %
#      epoch 5, minibatch 143/143, test error of best model 56.911765 %
# training @ iter =  800
# ...

# %%
from loadModel import loadModel
loadModel()
